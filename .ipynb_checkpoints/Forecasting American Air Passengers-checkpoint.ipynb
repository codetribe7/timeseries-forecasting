# %% [markdown]
# Reference: https://www.digitalocean.com/community/tutorials/a-guide-to-time-series-forecasting-with-prophet-in-python-3

# %%
# %matplotlib inline
import pandas as pd
from fbprophet import Prophet

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('AirPassengers.csv')
df.head()
# Out:
#      Month  AirPassengers
# 0  1949-01            112
# 1  1949-02            118
# 2  1949-03            132
# 3  1949-04            129
# 4  1949-05            121

# %%
df.dtypes
# Out:
# Month            object
# AirPassengers     int64
# dtype: object

# %%
df['Month'] = pd.DatetimeIndex(df['Month'])
df.dtypes
# Out:
# Month            datetime64[ns]
# AirPassengers             int64
# dtype: object

# %%
df.head()
# Out:
#        Month  AirPassengers
# 0 1949-01-01            112
# 1 1949-02-01            118
# 2 1949-03-01            132
# 3 1949-04-01            129
# 4 1949-05-01            121

# %%
df = df.rename(columns={'Month': 'ds', 'AirPassengers': 'y'})

df.head()
# Out:
#           ds    y
# 0 1949-01-01  112
# 1 1949-02-01  118
# 2 1949-03-01  132
# 3 1949-04-01  129
# 4 1949-05-01  121

# %%
ax = df.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Monthly Number of Airline Passengers')
ax.set_xlabel('Date')
# Out:
# Text(0.5,0,'Date')

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model = Prophet(interval_width=0.95)

# the learning
my_model.fit(df)
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /home/ak/anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
df.tail()
# Out:
#             ds    y
# 139 1960-08-01  606
# 140 1960-09-01  508
# 141 1960-10-01  461
# 142 1960-11-01  390
# 143 1960-12-01  432

# %%
future_dates = my_model.make_future_dataframe(periods=36, freq='MS')
future_dates.tail()
# Out:
#             ds
# 175 1963-08-01
# 176 1963-09-01
# 177 1963-10-01
# 178 1963-11-01
# 179 1963-12-01

# %%
future_dates.head()
# Out:
#           ds
# 0 1949-01-01
# 1 1949-02-01
# 2 1949-03-01
# 3 1949-04-01
# 4 1949-05-01

# %%
forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 175 1963-08-01  649.822900  603.567351  695.681099
# 176 1963-09-01  602.508589  553.541754  651.964392
# 177 1963-10-01  566.323180  521.596431  613.868944
# 178 1963-11-01  534.463209  491.809727  579.917696
# 179 1963-12-01  564.059804  520.501409  611.864413

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
#           ds        yhat  yhat_lower  yhat_upper
# 0 1949-01-01   84.970084   41.233754  127.773385
# 1 1949-02-01   78.457383   34.094612  123.043697
# 2 1949-03-01  110.108250   65.078156  155.466022
# 3 1949-04-01  107.780027   65.411890  153.037968
# 4 1949-05-01  111.193258   66.742145  155.131399

# %%
my_model.plot(forecast, uncertainty=True)

# %%
my_model.plot_components(forecast)
